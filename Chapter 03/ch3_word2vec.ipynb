# %% [markdown]
# # Chapter 3: Word2vec - Learning Word Embeddings

# %%
# !pip install adjustText
# Out:
# Collecting adjustText
#   Downloading adjustText-0.8-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from adjustText) (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from adjustText) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.16.0)
# Installing collected packages: adjustText
# Successfully installed adjustText-0.8

# %%
# %matplotlib inline
import zipfile
import re
import numpy as np
import pandas as pd
import os
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
from adjustText import adjust_text

# %% [markdown]
# ## Understanding the data
# ### Downloading the data
# This code downloads a BBC dataset consisting of news articles published by BBC.

# %%
def download_data(url, data_dir):
    """Download a file if not present, and make sure it's the right size."""
    os.makedirs(data_dir, exist_ok=True)

    file_path = os.path.join(data_dir, 'bbc-fulltext.zip')

    if not os.path.exists(file_path):
        print('Downloading file...')
        filename, _ = urlretrieve(url, file_path)
    else:
        print("File already exists")

    extract_path = os.path.join(data_dir, 'bbc')
    if not os.path.exists(extract_path):
        with zipfile.ZipFile(os.path.join(data_dir, 'bbc-fulltext.zip'), 'r') as zipf:
            zipf.extractall(data_dir)
    else:
        print("bbc-fulltext.zip has already been extracted")

url = 'http://mlg.ucd.ie/files/datasets/bbc-fulltext.zip'
download_data(url, 'data')
# Out:
# File already exists

# %% [markdown]
# ## Read Data without Preprocessing
# Reads data as it is to a string and tokenize it using spaces and returns a list of words

# %%
def read_data(data_dir):
    # This will contain the full list of stories
    news_stories = []

    print("Reading files")

    i = 0 # Just used for printing progress
    for root, dirs, files in os.walk(data_dir):

        for fi, f in enumerate(files):

            # We don't read the readme file
            if 'README' in f:
                continue

            # Printing progress
            i += 1
            print("."*i, f, end='\r')

            # Open the file
            with open(os.path.join(root, f), encoding='latin-1') as f:

                story = []
                # Read all the lines
                for row in f:

                    story.append(row.strip())

                # Create a single string with all the rows in the doc
                story = ' '.join(story)
                # Add that to the list
                news_stories.append(story)

        print('', end='\r')

    print(f"\nDetected {len(news_stories)} stories")
    return news_stories


news_stories = read_data(os.path.join('data', 'bbc'))

# Printing some stats and sample data
print(f"{sum([len(story.split(' ')) for story in news_stories])} words found in the total news set")
print('Example words (start): ',news_stories[0][:50])
print('Example words (end): ',news_stories[-1][-50:])
# Out:
# Reading files
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................. 182.txt
# Detected 2225 stories
# 865163 words found in the total news set
# Example words (start):  Brown hits back in Blair rift row  Gordon Brown ha
# Example words (end):  e the projected eurozone average of just above 2%.

# %% [markdown]
# ## Build a Tokenizer

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(num_words=None,
                      filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
                      lower=True,
                      split=' ')

tokenizer.fit_on_texts(news_stories)
print("Data fitted on the tokenizer")
# Out:
# Data fitted on the tokenizer

# %% [markdown]
# ## Exploring the tokenizer

# %%
n_vocab = len(tokenizer.word_index.items()) + 1
print(f"Vocabulary size: {n_vocab}")

print("\nWords at the top")
print('\t', dict(list(tokenizer.word_index.items())[:10]))
print("\nWords at the bottom")
print('\t', dict(list(tokenizer.word_index.items())[-10:]))
# Out:
# Vocabulary size: 32360
#
# Words at the top
# 	 {'the': 1, 'to': 2, 'of': 3, 'and': 4, 'a': 5, 'in': 6, 'for': 7, 'is': 8, 'that': 9, 'on': 10}
#
# Words at the bottom
# 	 {"drug's": 32350, "pharma's": 32351, 'spray': 32352, 'satifex': 32353, 'tetrahydrocannabinol': 32354, 'cannabidiol': 32355, 'arthritis': 32356, "sativex's": 32357, 'buffets': 32358, 'touati': 32359}

# %% [markdown]
# ## Build a Tokenizer (Refined)
# Here, we will restrict the vocabulary to 15000 and eleminate words except the first most common 15000 words

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

n_vocab = 15000 + 1
tokenizer = Tokenizer(
    num_words=n_vocab-1,
    filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
    lower=True, split=' ', oov_token='',
)

tokenizer.fit_on_texts(news_stories)
print("Data fitted on the tokenizer")
# Out:
# Data fitted on the tokenizer

# %% [markdown]
# ### Checking the results of the tokenizer

# %%
print(f"Original: {news_stories[0][:100]}")
print(f"Sequence IDs: {tokenizer.texts_to_sequences([news_stories[0][:100]])[0]}")
# Out:
# Original: Brown hits back in Blair rift row  Gordon Brown has criticised a union leader who said conflict betw
# Sequence IDs: [237, 1373, 96, 7, 169, 3938, 1016, 760, 237, 19, 1239, 6, 600, 357, 46, 12, 2907, 1]

# %% [markdown]
# ### Converting all articles to word ID sequences

# %%
news_sequences = tokenizer.texts_to_sequences(news_stories)

# %% [markdown]
# ## Generating skip-grams from the corpus
# In TensorFlow we have the convenient `tf.keras.preprocessing.sequence.skipgrams()` function to generate skipgrams.

# %%
sample_word_ids = news_sequences[0][:5]
sample_phrase = ' '.join([tokenizer.index_word[wid] for wid in sample_word_ids])
print(f"Sample phrase: {sample_phrase}")
print(f"Sample word IDs: {sample_word_ids }\n")
# Out:
# Sample phrase: brown hits back in blair
# Sample word IDs: [237, 1373, 96, 7, 169]

# %%
window_size = 1 # How many words to consider left and right.

inputs, labels = tf.keras.preprocessing.sequence.skipgrams(
    sequence=sample_word_ids,
    vocabulary_size=n_vocab,
    window_size=window_size,
    negative_samples=1.0,
    shuffle=False,
    categorical=False,
    sampling_table=None,
    seed=None)

print("Sample skip-grams")

for inp, lbl in zip(inputs, labels):
    print(f"\tInput: {inp} ({[tokenizer.index_word[wi] for wi in inp]}) / Label: {lbl}")
# Out:
# Sample skip-grams
# 	Input: [237, 1373] (['brown', 'hits']) / Label: 1
# 	Input: [1373, 237] (['hits', 'brown']) / Label: 1
# 	Input: [1373, 96] (['hits', 'back']) / Label: 1
# 	Input: [96, 1373] (['back', 'hits']) / Label: 1
# 	Input: [96, 7] (['back', 'in']) / Label: 1
# 	Input: [7, 96] (['in', 'back']) / Label: 1
# 	Input: [7, 169] (['in', 'blair']) / Label: 1
# 	Input: [169, 7] (['blair', 'in']) / Label: 1
# 	Input: [7, 383] (['in', 'current']) / Label: 0
# 	Input: [169, 990] (['blair', 'technologies']) / Label: 0
# 	Input: [96, 11133] (['back', 'sustainability']) / Label: 0
# 	Input: [1373, 9004] (['hits', 'conflicting']) / Label: 0
# 	Input: [1373, 5922] (['hits', 'remembered']) / Label: 0
# 	Input: [237, 11328] (['brown', 'lammy']) / Label: 0
# 	Input: [7, 3100] (['in', 'vehicle']) / Label: 0
# 	Input: [96, 12730] (['back', 'awarding']) / Label: 0

# %% [markdown]
# ## Generating negative candidates
# Word2vec algorithms rely on negative candidates to understand words that do not appear in the context of a given target word.

# %%
inputs, labels = tf.keras.preprocessing.sequence.skipgrams(
    sample_word_ids,
    vocabulary_size=len(tokenizer.word_index.items())+1,
    window_size=window_size,
    negative_samples=0,
    shuffle=False)

inputs, labels = np.array(inputs), np.array(labels)

# %%
negative_sampling_candidates, true_expected_count, sampled_expected_count \
= tf.random.log_uniform_candidate_sampler(
    # A true context word that appears in the context of the target
    true_classes=inputs[:1, :1], # [b, 1] sized vector
    num_true=1,
    num_sampled=10,
    unique=True,
    range_max=n_vocab,
    name="negative_sampling"
)

print(f"Positive sample: {inputs[:1,1:]}")
print(f"Negative samples: {negative_sampling_candidates}")
print(f"true_expected_count: {true_expected_count}")
print(f"sampled_expected_count: {sampled_expected_count}")
# Out:
# Positive sample: [[1373]]
# Negative samples: [1776    0 3526   29 1085   71 1180   47 3976   69]
# true_expected_count: [[0.00521988]]
# sampled_expected_count: [7.0184335e-04 5.9251773e-01 3.5371390e-04 4.0160567e-02 1.1479720e-03
#  1.7077921e-02 1.0557125e-03 2.5430080e-02 3.1370172e-04 1.7558495e-02]

# %% [markdown]
# ## Using `tf.nn.sampled_softmax_loss()`

# %%
sampling_table = tf.keras.preprocessing.sequence.make_sampling_table(n_vocab, sampling_factor=1e-05)
print(sampling_table)
# Out:
# [0.00315225 0.00315225 0.00547597 ... 1.         1.         1.        ]

# %% [markdown]
# ## Generating data (positive + negative candidates)

# %%
def skip_gram_data_generator(sequences, window_size, batch_size, negative_samples, vocab_size, seed=None):

    rand_sequence_ids = np.arange(len(sequences))
    np.random.shuffle(rand_sequence_ids)


    for si in rand_sequence_ids:

        positive_skip_grams, _ = tf.keras.preprocessing.sequence.skipgrams(
            sequences[si],
            vocabulary_size=vocab_size,
            window_size=window_size,
            negative_samples=0.0,
            shuffle=False,
            sampling_table=sampling_table,
            seed=seed
        )

        targets, contexts, labels = [], [], []

        for target_word, context_word in positive_skip_grams:
            context_class = tf.expand_dims(tf.constant([context_word], dtype="int64"), 1)

            negative_sampling_candidates, _, _ = tf.random.log_uniform_candidate_sampler(
              true_classes=context_class,
              num_true=1,
              num_sampled=negative_samples,
              unique=True,
              range_max=vocab_size,
              name="negative_sampling")

            # Build context and label vectors (for one target word)
            context = tf.concat(
                [tf.constant([context_word], dtype='int64'), negative_sampling_candidates],
                axis=0
            )

            label = tf.constant([1] + [0]*negative_samples, dtype="int64")

            # Append each element from the training example to global lists.
            targets.extend([target_word]*(negative_samples+1))
            contexts.append(context)
            labels.append(label)

        contexts, targets, labels = np.concatenate(contexts), np.array(targets), np.concatenate(labels)

        assert contexts.shape[0] == targets.shape[0]
        assert contexts.shape[0] == labels.shape[0]

        # If seed is not provided generate a random one
        if not seed:
            seed = random.randint(0, 10e6)

        np.random.seed(seed)
        np.random.shuffle(contexts)
        np.random.seed(seed)
        np.random.shuffle(targets)
        np.random.seed(seed)
        np.random.shuffle(labels)


        for eg_id_start in range(0, contexts.shape[0], batch_size):
            yield (
                targets[eg_id_start: min(eg_id_start+batch_size, targets.shape[0])],
                contexts[eg_id_start: min(eg_id_start+batch_size, contexts.shape[0])]
            ), labels[eg_id_start: min(eg_id_start+batch_size, labels.shape[0])]

news_skip_gram_gen = skip_gram_data_generator(
    news_sequences, 4, 10, 5, n_vocab
)

for btc, bl in news_skip_gram_gen:

    print(btc)
    print(bl)

    break
# Out:
# (array([ 422, 6787, 5934,    6, 3083, 4737, 3083, 1075, 2135,  995]), array([ 6914,    46,   667, 14448,     0,   728,    10,    20,    18,
#            0]))
# [0 0 1 0 0 0 1 0 0 0]

# %% [markdown]
# ## Skip-Gram Algorithm
# ### Defining Hyperparameters
# Here we define several hyperparameters including `batch_size` (amount of samples in a single batch) `embedding_size` (size of embedding vectors) `window_size` (context window size).

# %%
batch_size = 4096 # Data points in a single batch

embedding_size = 128 # Dimension of the embedding vector.

window_size=1 # We use a window size of n on either side of target word
negative_samples = 4 # Number of negative samples generated per example

epochs = 5 # Number of epochs to train for

# We pick a random validation set to sample nearest neighbors
valid_size = 16 # Random set of words to evaluate similarity on.
# We sample valid datapoints randomly from a large window without always being deterministic
valid_window = 250

# When selecting valid examples, we select some of the most frequent words as well as
# some moderately rare words as well
np.random.seed(54321)
random.seed(54321)

valid_term_ids = np.array(random.sample(range(valid_window), valid_size))
valid_term_ids = np.append(
    valid_term_ids, random.sample(range(1000, 1000+valid_window), valid_size),
    axis=0
)

# %% [markdown]
# ### Defining the Model
# Here we will define the skip-gram model. It contains two embedding layers; context and target embeddings. The final output is computed as the dot product between the corresponding lookups from the context and target embeddings for a given batch of context and target words.

# %%
import tensorflow.keras.backend as K
K.clear_session()

# Inputs - skipgrams() function outputs target, context in that order
input_1 = tf.keras.layers.Input(shape=(), name='target')
input_2 = tf.keras.layers.Input(shape=(), name='context')

# Two embeddings layers are used one for the context and one for the
# target
target_embedding_layer = tf.keras.layers.Embedding(
    input_dim=n_vocab, output_dim=embedding_size,
    name='target_embedding'
)

context_embedding_layer = tf.keras.layers.Embedding(
    input_dim=n_vocab, output_dim=embedding_size,
    name='context_embedding'
)

# Lookup outputs of the embedding layers
target_out = target_embedding_layer(input_1)
context_out = context_embedding_layer(input_2)

# Computing the dot product between the two
out = tf.keras.layers.Dot(axes=-1)([context_out, target_out])

# Defining the model
skip_gram_model = tf.keras.models.Model(inputs=[input_1, input_2],
outputs=out, name='skip_gram_model')

# Compiling the model
skip_gram_model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                        optimizer='adam',
                        metrics=['accuracy'])

skip_gram_model.summary()
# Out:
# Model: "skip_gram_model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  context (InputLayer)        [(None,)]                    0         []
#
#  target (InputLayer)         [(None,)]                    0         []
#
#  context_embedding (Embeddi  (None, 128)                  1920128   ['context[0][0]']
#  ng)
#
#  target_embedding (Embeddin  (None, 128)                  1920128   ['target[0][0]']
#  g)
#
#  dot (Dot)                   (None, 1)                    0         ['context_embedding[0][0]',
#                                                                      'target_embedding[0][0]']
#
# ==================================================================================================
# Total params: 3840256 (14.65 MB)
# Trainable params: 3840256 (14.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Calculating Word Similarities
# We calculate the similarity between two given words in terms of the cosine distance. To do this efficiently we use matrix operations to do so, as shown below. Furthermore, we define the computations as a callback, which will automatically run at the end of an epoch during model training.

# %%
class ValidationCallback(tf.keras.callbacks.Callback):

    def __init__(self, valid_term_ids, model_with_embeddings, tokenizer):

        self.valid_term_ids = valid_term_ids
        self.model_with_embeddings = model_with_embeddings
        self.tokenizer = tokenizer

        super().__init__()

    def on_epoch_end(self, epoch, logs=None):
        """ Validation logic """

        # We will use context embeddings to get the most similar words
        # Other strategies include: using target embeddings, mean embeddings after avaraging context/target
        embedding_weights = self.model_with_embeddings.get_layer("context_embedding").get_weights()[0]
        normalized_embeddings = embedding_weights / np.sqrt(np.sum(embedding_weights**2, axis=1, keepdims=True))

        # Get the embeddings corresponding to valid_term_ids
        valid_embeddings = normalized_embeddings[self.valid_term_ids, :]

        # Compute the similarity between valid_term_ids and all the embeddings
        # V x d (d x D) => V x D
        top_k = 5 # Top k items will be displayed
        similarity = np.dot(valid_embeddings, normalized_embeddings.T)

        # Invert similarity matrix to negative
        # Ignore the first one because that would be the same word as the probe word
        similarity_top_k = np.argsort(-similarity, axis=1)[:, 1: top_k+1]

        # Print the output
        for i, term_id in enumerate(valid_term_ids):

            similar_word_str = ', '.join([self.tokenizer.index_word[j] for j in similarity_top_k[i, :] if j >= 1])
            print(f"{self.tokenizer.index_word[term_id]}: {similar_word_str}")

        print('\n')

# %% [markdown]
# ### Running the Skip-Gram Algorithm

# %%
skipgram_validation_callback = ValidationCallback(valid_term_ids, skip_gram_model, tokenizer)

for ei in range(epochs):

    print(f"Epoch: {ei+1}/{epochs} started")

    news_skip_gram_gen = skip_gram_data_generator(
        news_sequences, window_size, batch_size, negative_samples, n_vocab
    )

    skip_gram_model.fit(
        news_skip_gram_gen, epochs=1,
        callbacks=skipgram_validation_callback,
    )
# Out:
# Epoch: 1/5 started
#    2233/Unknown - 553s 244ms/step - loss: 0.5729 - accuracy: 0.8004election: story, wednesday, couple, led
# me: able, now, lords, due
# with: source, could, respond, around, blending
# you: now, still, me, they, don't
# were: only, need, beijing, get, go
# win: case, chance, kind, idea
# those: ensure, able, meet, ball
# music: expected, end, story, technology
# also: you, now, what, don't, them
# international: wes, according, provided, putting
# best: find, end, fear, give
# him: lead, able, due, provide
# too: go, only, able, trying
# into: during, corner, bottle, then
# through: fold, current, interview, chance
# mr: tony, dan, , said, launching
# davis: victory, story, described, heineken, young
# concern: willing, bring, introduction, built
# trading: functionality, show, seriously, likes
# critics: mps, willing, end, seeing
# post: end, back, sport, digital
# details: much, fact, used, ball
# approach: set, months, story, win
# previously: unlikely, run, do, nature, attempting
# measures: able, chance, need, worse
# actually: play, chance, need, do
# deutsche: embarrassed, issue, anfield, week, able
# leaders: end, order, run, made
# asylum: futures, deny, built, nots
# attempt: kind, likely, going, keen
# reached: august, chance, value, fought
# illegal: bed, nurses, grasp, turned, keegan
#
#
# 2233/2233 [==============================] - 554s 244ms/step - loss: 0.5729 - accuracy: 0.8004
# Epoch: 2/5 started
#    2233/Unknown - 447s 200ms/step - loss: 0.4604 - accuracy: 0.8055election: attorney, elections, motors, membership, trial
# me: probably, tories, him, them, things
# with: reducing, inciting, uncertainties, across, against
# you: they, don't, we, never, me
# were: are, was, being, have, been
# win: jumps, 1963, travis, kind, wallabies
# those: readily, technicians, belong, chairmanship, hurdle
# music: rsa, topic, os, nominations, alter
# also: never, now, actually, already, previously
# international: policy, fund, glory, 'the, tracker
# best: supporting, category, friends, arrests, reunion
# him: them, me, didn't, explanations, anything
# too: because, we've, suspiciously, digitised, we'll
# into: during, 1967, entertain, kensington, preliminary
# through: we'd, furious, couples, protest, reforming
# mr: gordon, tony, jack, dan, michael
# davis: carling, fa, heineken, qualifiers, clash
# concern: 1982, livelihoods, radicati, weston, lucent
# trading: obey, functionality, ideal, stripped, ditch
# critics: spitting, realising, bound, precursor, thx
# post: bike, slovenia, rattled, 1964
# details: pray, exception, dimensions, trigger
# approach: workings, reinforce, knock, erewash, digits
# previously: depend, everything, lakhani, tories, she's
# measures: argue, reunion, investigated, retire, hammer
# actually: probably, never, do, really, just
# deutsche: embarrassed, anfield, occupying, 6km, overnight
# leaders: delivery, regard, repeat, â£35m, ceremonies
# asylum: kaplan, aren't, tuned, dealt, apart
# attempt: rare, addition, wake, tens
# reached: throw, haunt, retained, podcast
# illegal: detentions, giselle, mencap, walls, complied
#
#
# 2233/2233 [==============================] - 447s 200ms/step - loss: 0.4604 - accuracy: 0.8055
# Epoch: 3/5 started
#    2233/Unknown - 435s 195ms/step - loss: 0.4215 - accuracy: 0.8136election: motors, elections, trial, atmosphere, buzz
# me: probably, seriously, tories, able, him
# with: saul, one's, between, reducing, against
# you: they, don't, we, doesn't, probably
# were: are, we're, significantly, being, have
# win: rosenborg, us', excitement, 1500m, behalf
# those: readily, wasn't, viruses, inadvertently, gamers
# music: refuseniks, cameras, flagship, grammy, kitchen
# also: previously, already, consistently, formally, now
# international: policy, fund, england's, glory, bank's
# best: category, supporting, romantic, economies, jailhouse
# him: them, me, themselves, lots, doesn't
# too: better, very, bit, we've, worse
# into: during, preliminary, marked, sec's, sustaining
# through: ageism, catching, closer, codes, bugs
# mr: tony, gordon, jack, michael, malcolm
# davis: qualifiers, carling, frost, fa, southampton's
# concern: aggravating, rosenborg, variety, prosecuted, region
# trading: mozambique, functionality, checking, plotting, reoffending
# critics: violate, straightforward, palestinians, chronology, mps
# post: beige, thigh, blinx, showcasing, adaptation
# details: favour, reason, context, twickenham, lack
# approach: factors, libertarian, context, procedures, undertaking
# previously: consistently, everything, also, we've, herself
# measures: argue, dampened, retire, signature, harder
# actually: probably, everything, anything, never, always
# deutsche: austria's, energis, weekend, failing, austria
# leaders: convention, progressing, constitution, coffers, respectable
# asylum: deny, genuinely, kaplan, hoped, nogar
# attempt: inducted, nurses, rare, addition, generate
# reached: hanover, haunt, joke, 96bn, eliminating
# illegal: bearing, nursery, unintentional, offshore, yahoo's
#
#
# 2233/2233 [==============================] - 435s 195ms/step - loss: 0.4215 - accuracy: 0.8136
# Epoch: 4/5 started
#    2233/Unknown - 433s 194ms/step - loss: 0.3914 - accuracy: 0.8227election: motors, elections, attorney, trial, colonial
# me: probably, seriously, she's, they'll, able
# with: one's, relaxation, reservoir, saul, headset
# you: probably, don't, we, they, doesn't
# were: are, being, separately, have, been
# win: 1500m, glory, rosenborg, jumps, tourists
# those: readily, worse, rightly, inadvertently, gamers
# music: cameras, unlimited, recording, media, flagship
# also: previously, already, repeatedly, recently, she's
# international: policy, england's, scottish, fund, glory
# best: category, supporting, artist, jailhouse, child's
# him: them, me, explanations, themselves, lots
# too: better, very, bit, less, worse
# into: thumb, towards, upward, transforming, racism
# through: towards, ageism, ahead, closer, codes
# mr: tony, jack, gordon, ken, malcolm
# davis: carling, qualifiers, munster, frost, heineken
# concern: walkman, prosecuted, region, calls, walkouts
# trading: functionality, pubs, understated, reoffending, years'
# critics: readily, they'd, inherently, palestinians, lta
# post: blow, tier, novo, driver, conflict
# details: favour, backbone, advantages, warcraft, minidisc
# approach: manner, luck, libertarian, believer, tenure
# previously: repeatedly, everything, she's, clearly, she
# measures: argue, matter, virtually, worsened, plenty
# actually: everything, wrong, probably, never, strongly
# deutsche: austria's, energis, austria, buildings, greenfield
# leaders: fulham, convention, eviction, dancers, table
# asylum: frustrated, nogar, kaplan, cea, they'll
# attempt: tracts, inducted, difference, favour, intention
# reached: edged, advent, mcgeady, 96bn, haunt
# illegal: steady, slack, bearing, placing, investing
#
#
# 2233/2233 [==============================] - 433s 194ms/step - loss: 0.3914 - accuracy: 0.8227
# Epoch: 5/5 started
#    2233/Unknown - 440s 197ms/step - loss: 0.3654 - accuracy: 0.8322election: motors, colonial, spring, labour's, season's
# me: she's, probably, seriously, detentions, they'll
# with: one's, saul, atlantic, reservoir, relaxation
# you: doesn't, probably, we, i'd, don't
# were: are, separately, legally, partly, those
# win: colchester, glory, 1500m, 200m, choose
# those: gamers, wasn't, readily, unfounded, worse
# music: cameras, unlimited, recording, refuseniks, enter
# also: previously, already, repeatedly, initially, finally
# international: scottish, policy, 200m, football, fund
# best: category, supporting, artist, child's, quirky
# him: them, me, explanations, themselves, she's
# too: better, very, less, increasingly, extremely
# into: towards, thumb, onto, wisely, 28th
# through: ahead, towards, kids, ageism, walder
# mr: tony, jack, gordon, malcolm, ken
# davis: munster, carling, heineken, frost, tottenham
# concern: doubts, systematically, walkman, portsmouth, stress
# trading: cartoon, pledges, checking, qualities, hitting
# critics: they'd, inherently, god, advocates, tories
# post: tier, disaster, unidentified, blow, amazon's
# details: element, talents, grab, inclusion, years'
# approach: luck, supporter, believer, insight, chunk
# previously: repeatedly, publicly, they've, herself, clearly
# measures: recovered, sleep, signature, narrowing, plenty
# actually: never, we'll, poorly, probably, everything
# deutsche: austria's, austria, boosts, mellon, energis
# leaders: fulham, zurich, eviction, pixies, joining
# asylum: they'll, restricting, gsm, why, polls
# attempt: brick, dip, generate, inducted, tracts
# reached: scrap, edged, 96bn, â£400m, averaged
# illegal: steroids, citing, cgi, slack, banning
#
#
# 2233/2233 [==============================] - 440s 197ms/step - loss: 0.3654 - accuracy: 0.8322

# %%
def save_embeddings(model, tokenizer, vocab_size, save_dir):

    os.makedirs(save_dir, exist_ok=True)

    _, words_sorted = zip(*sorted(list(tokenizer.index_word.items()), key=lambda x: x[0])[:vocab_size-1])

    words_sorted = [None] + list(words_sorted)

    pd.DataFrame(
        model.get_layer("context_embedding").get_weights()[0],
        index = words_sorted
    ).to_pickle(os.path.join(save_dir, "context_embedding.pkl"))

    pd.DataFrame(
        model.get_layer("target_embedding").get_weights()[0],
        index = words_sorted
    ).to_pickle(os.path.join(save_dir, "target_embedding.pkl"))


save_embeddings(skip_gram_model, tokenizer, n_vocab, save_dir='skipgram_embeddings')

# %% [markdown]
# ## CBOW Algorithm

# %%
def cbow_grams(sequence, vocabulary_size,
              window_size=4, negative_samples=1., shuffle=True,
              categorical=False, sampling_table=None, seed=None):

    targets, contexts, labels = [], [], []

    for i, wi in enumerate(sequence):


        if not wi or i < window_size or i + 1 > len(sequence)-window_size:
            continue
        if sampling_table is not None:
            if sampling_table[wi] < random.random():
                continue

        window_start = max(0, i - window_size)
        window_end = min(len(sequence), i + window_size + 1)

        context_words = [wj for j, wj in enumerate(sequence[window_start:window_end]) if j+window_start != i]
        target_word = wi

        context_classes = tf.expand_dims(tf.constant(context_words, dtype="int64"), 0)

        negative_sampling_candidates, _, _ = tf.random.log_uniform_candidate_sampler(
          true_classes=context_classes,
          num_true=window_size * 2,
          num_sampled=negative_samples,
          unique=True,
          range_max=vocabulary_size,
          name="negative_sampling")

        # Build context and label vectors (for one target word)
        negative_targets = negative_sampling_candidates.numpy().tolist()

        target = [target_word] + negative_targets
        label = [1] + [0]*negative_samples

        # Append each element from the training example to global lists.
        targets.extend(target)
        contexts.extend([context_words]*(negative_samples+1))
        labels.extend(label)

    couples = list(zip(targets, contexts))

    seed = random.randint(0, 10e6)
    random.seed(seed)
    random.shuffle(couples)
    random.seed(seed)
    random.shuffle(labels)


    return couples, labels

window_size = 1 # How many words to consider left and right.

inputs, labels = cbow_grams(
    tokenizer.texts_to_sequences(["I am going to the store"])[0],
    vocabulary_size=len(tokenizer.word_index.items())+1,
    window_size=window_size, negative_samples=4, shuffle=False,
    categorical=False, sampling_table=None, seed=None
)

print(tokenizer.texts_to_sequences(["I am going to the store"]))
i = 0
for inp, lbl in zip(inputs, labels):
    i += 1
    print(f"Input: {inp} ({[[tokenizer.index_word[wi] for wi in inp[1] ]] + [tokenizer.index_word[inp[0]] if inp[0] > 0 else None]})/ Label: {lbl}")
    #
    if i >= 20:
        break
# Out:
# [[28, 428, 132, 3, 2, 1497]]
# Input: (3, [132, 2]) ([['going', 'the'], 'to'])/ Label: 1
# Input: (4, [428, 3]) ([['am', 'to'], 'of'])/ Label: 0
# Input: (428, [28, 132]) ([['i', 'going'], 'am'])/ Label: 1
# Input: (5201, [28, 132]) ([['i', 'going'], 'buyer'])/ Label: 0
# Input: (111, [132, 2]) ([['going', 'the'], 'set'])/ Label: 0
# Input: (22084, [3, 1497]) ([['to', 'store'], 'hutus'])/ Label: 0
# Input: (283, [428, 3]) ([['am', 'to'], 'despite'])/ Label: 0
# Input: (3, [3, 1497]) ([['to', 'store'], 'to'])/ Label: 0
# Input: (2, [3, 1497]) ([['to', 'store'], 'the'])/ Label: 1
# Input: (1296, [132, 2]) ([['going', 'the'], "party's"])/ Label: 0
# Input: (138, [3, 1497]) ([['to', 'store'], 'games'])/ Label: 0
# Input: (1474, [28, 132]) ([['i', 'going'], 'putting'])/ Label: 0
# Input: (18899, [28, 132]) ([['i', 'going'], 'ample'])/ Label: 0
# Input: (1, [428, 3]) ([['am', 'to'], ''])/ Label: 0
# Input: (87, [28, 132]) ([['i', 'going'], 'being'])/ Label: 0
# Input: (132, [428, 3]) ([['am', 'to'], 'going'])/ Label: 1
# Input: (25300, [3, 1497]) ([['to', 'store'], 'britneys'])/ Label: 0
# Input: (1030, [132, 2]) ([['going', 'the'], 'images'])/ Label: 0
# Input: (32, [132, 2]) ([['going', 'the'], 'this'])/ Label: 0
# Input: (8189, [428, 3]) ([['am', 'to'], 'gameboyzz'])/ Label: 0

# %%
window_size = 1 # How many words to consider left and right.

inputs, labels = tf.keras.preprocessing.sequence.skipgrams(
    tokenizer.texts_to_sequences([news_stories[0][:150]])[0],
    vocabulary_size=len(tokenizer.word_index.items())+1,
    window_size=window_size, negative_samples=4, shuffle=False,
    categorical=False, sampling_table=None, seed=None
)

i = 0
for inp, lbl in zip(inputs, labels):
    i += 1
    print(f"Input: {inp} ({[tokenizer.index_word[wi] for wi in inp]}) / Label: {lbl}")
# Out:
# Input: [237, 1373] (['brown', 'hits']) / Label: 1
# Input: [1373, 237] (['hits', 'brown']) / Label: 1
# Input: [1373, 96] (['hits', 'back']) / Label: 1
# Input: [96, 1373] (['back', 'hits']) / Label: 1
# Input: [96, 7] (['back', 'in']) / Label: 1
# Input: [7, 96] (['in', 'back']) / Label: 1
# Input: [7, 169] (['in', 'blair']) / Label: 1
# Input: [169, 7] (['blair', 'in']) / Label: 1
# Input: [169, 3938] (['blair', 'rift']) / Label: 1
# Input: [3938, 169] (['rift', 'blair']) / Label: 1
# Input: [3938, 1016] (['rift', 'row']) / Label: 1
# Input: [1016, 3938] (['row', 'rift']) / Label: 1
# Input: [1016, 760] (['row', 'gordon']) / Label: 1
# Input: [760, 1016] (['gordon', 'row']) / Label: 1
# Input: [760, 237] (['gordon', 'brown']) / Label: 1
# Input: [237, 760] (['brown', 'gordon']) / Label: 1
# Input: [237, 19] (['brown', 'has']) / Label: 1
# Input: [19, 237] (['has', 'brown']) / Label: 1
# Input: [19, 1239] (['has', 'criticised']) / Label: 1
# Input: [1239, 19] (['criticised', 'has']) / Label: 1
# Input: [1239, 6] (['criticised', 'a']) / Label: 1
# Input: [6, 1239] (['a', 'criticised']) / Label: 1
# Input: [6, 600] (['a', 'union']) / Label: 1
# Input: [600, 6] (['union', 'a']) / Label: 1
# Input: [600, 357] (['union', 'leader']) / Label: 1
# Input: [357, 600] (['leader', 'union']) / Label: 1
# Input: [357, 46] (['leader', 'who']) / Label: 1
# Input: [46, 357] (['who', 'leader']) / Label: 1
# Input: [46, 12] (['who', 'said']) / Label: 1
# Input: [12, 46] (['said', 'who']) / Label: 1
# Input: [12, 2907] (['said', 'conflict']) / Label: 1
# Input: [2907, 12] (['conflict', 'said']) / Label: 1
# Input: [2907, 157] (['conflict', 'between']) / Label: 1
# Input: [157, 2907] (['between', 'conflict']) / Label: 1
# Input: [157, 912] (['between', 'himself']) / Label: 1
# Input: [912, 157] (['himself', 'between']) / Label: 1
# Input: [912, 5] (['himself', 'and']) / Label: 1
# Input: [5, 912] (['and', 'himself']) / Label: 1
# Input: [5, 487] (['and', 'tony']) / Label: 1
# Input: [487, 5] (['tony', 'and']) / Label: 1
# Input: [487, 169] (['tony', 'blair']) / Label: 1
# Input: [169, 487] (['blair', 'tony']) / Label: 1
# Input: [169, 14] (['blair', 'was']) / Label: 1
# Input: [14, 169] (['was', 'blair']) / Label: 1
# Input: [14, 1] (['was', '']) / Label: 1
# Input: [1, 14] (['', 'was']) / Label: 1
# Input: [1, 2] (['', 'the']) / Label: 1
# Input: [2, 1] (['the', '']) / Label: 1
# Input: [2, 393] (['the', 'working']) / Label: 1
# Input: [393, 2] (['working', 'the']) / Label: 1
# Input: [912, 12177] (['himself', 'glaxosmithkline']) / Label: 0
# Input: [7, 3994] (['in', 'sit']) / Label: 0
# Input: [2, 23436] (['the', 'duffer']) / Label: 0
# Input: [169, 28472] (['blair', 'ssempgani']) / Label: 0
# Input: [6, 16197] (['a', 'afflicting']) / Label: 0
# Input: [46, 22797] (['who', 'rigours']) / Label: 0
# Input: [237, 18989] (['brown', 'ontrack']) / Label: 0
# Input: [12, 14187] (['said', 'felix']) / Label: 0
# Input: [1373, 19578] (['hits', 'daytime']) / Label: 0
# Input: [96, 30633] (['back', 'deplete']) / Label: 0
# Input: [5, 30633] (['and', 'deplete']) / Label: 0
# Input: [1, 7607] (['', 'cadbury']) / Label: 0
# Input: [2907, 4744] (['conflict', 'sum']) / Label: 0
# Input: [46, 17884] (['who', 'reminiscent']) / Label: 0
# Input: [1016, 12641] (['row', 'candid']) / Label: 0
# Input: [12, 32232] (['said', 'burberry']) / Label: 0
# Input: [169, 18487] (['blair', 'amputated']) / Label: 0
# Input: [600, 22353] (['union', 'approximation']) / Label: 0
# Input: [19, 30958] (['has', 'anson']) / Label: 0
# Input: [96, 23863] (['back', 'koumas']) / Label: 0
# Input: [487, 1582] (['tony', 'features']) / Label: 0
# Input: [3938, 25823] (['rift', 'gravity']) / Label: 0
# Input: [760, 21681] (['gordon', 'mammal']) / Label: 0
# Input: [14, 25289] (['was', 'squirreling']) / Label: 0
# Input: [7, 5954] (['in', 'grab']) / Label: 0
# Input: [1239, 16123] (['criticised', 'equate']) / Label: 0
# Input: [912, 25198] (['himself', "telegraaf's"]) / Label: 0
# Input: [157, 32081] (['between', 'unpayable']) / Label: 0
# Input: [14, 22946] (['was', "race's"]) / Label: 0
# Input: [1239, 30500] (['criticised', 'gustafson']) / Label: 0
# Input: [760, 14673] (['gordon', 'tno']) / Label: 0
# Input: [169, 19922] (['blair', 'wilbur']) / Label: 0
# Input: [2907, 21812] (['conflict', 'xenophobia']) / Label: 0
# Input: [237, 2843] (['brown', 'copy']) / Label: 0
# Input: [357, 17618] (['leader', 'wrapped']) / Label: 0
# Input: [487, 9592] (['tony', 'henderson']) / Label: 0
# Input: [1016, 19668] (['row', 'patti']) / Label: 0
# Input: [1, 24668] (['', 'recuperating']) / Label: 0
# Input: [357, 29770] (['leader', 'rockwell']) / Label: 0
# Input: [169, 7850] (['blair', 'flag']) / Label: 0
# Input: [237, 818] (['brown', "we're"]) / Label: 0
# Input: [2, 19922] (['the', 'wilbur']) / Label: 0
# Input: [600, 9297] (['union', 'nod']) / Label: 0
# Input: [3938, 32088] (['rift', '725m']) / Label: 0
# Input: [5, 5026] (['and', 'ljubicic']) / Label: 0
# Input: [1373, 16574] (['hits', 'doorstep']) / Label: 0
# Input: [157, 194] (['between', 'old']) / Label: 0
# Input: [19, 5586] (['has', 'u']) / Label: 0
# Input: [6, 22418] (['a', 'begging']) / Label: 0
# Input: [393, 25212] (['working', 'souter']) / Label: 0
# Input: [912, 28819] (['himself', 'stewardess']) / Label: 0
# Input: [7, 12939] (['in', 'gasoline']) / Label: 0
# Input: [2, 7270] (['the', 'sat']) / Label: 0
# Input: [169, 29855] (['blair', 'breuer']) / Label: 0
# Input: [6, 20233] (['a', 'cfd']) / Label: 0
# Input: [46, 27986] (['who', 'renaud']) / Label: 0
# Input: [237, 24499] (['brown', "poll's"]) / Label: 0
# Input: [12, 10442] (['said', 'hefty']) / Label: 0
# Input: [1373, 5177] (['hits', 'depend']) / Label: 0
# Input: [96, 12273] (['back', 'fashionable']) / Label: 0
# Input: [5, 15463] (['and', 'aefa']) / Label: 0
# Input: [1, 9936] (['', 'altria']) / Label: 0
# Input: [2907, 3190] (['conflict', '55']) / Label: 0
# Input: [46, 22446] (['who', 'wadi']) / Label: 0
# Input: [1016, 7034] (['row', 'redford']) / Label: 0
# Input: [12, 4000] (['said', 'guardian']) / Label: 0
# Input: [169, 30123] (['blair', '217']) / Label: 0
# Input: [600, 7342] (['union', 'flexible']) / Label: 0
# Input: [19, 896] (['has', 'brought']) / Label: 0
# Input: [96, 10199] (['back', 'alerted']) / Label: 0
# Input: [487, 23460] (['tony', 'etchi']) / Label: 0
# Input: [3938, 25505] (['rift', 'redesigning']) / Label: 0
# Input: [760, 29175] (['gordon', 'cunning']) / Label: 0
# Input: [14, 27687] (['was', 'sinew']) / Label: 0
# Input: [7, 10727] (['in', 'swearing']) / Label: 0
# Input: [1239, 16544] (['criticised', 'eccentric']) / Label: 0
# Input: [912, 17652] (['himself', 'olof']) / Label: 0
# Input: [157, 23187] (['between', "sotherton's"]) / Label: 0
# Input: [14, 27315] (['was', 'evergreen']) / Label: 0
# Input: [1239, 5675] (['criticised', 'gray']) / Label: 0
# Input: [760, 1994] (['gordon', 'replacement']) / Label: 0
# Input: [169, 13163] (['blair', 'amend']) / Label: 0
# Input: [2907, 11112] (['conflict', 'wpp']) / Label: 0
# Input: [237, 26727] (['brown', 'dayton']) / Label: 0
# Input: [357, 258] (['leader', 'future']) / Label: 0
# Input: [487, 25803] (['tony', 'heck']) / Label: 0
# Input: [1016, 25425] (['row', 'unshredded']) / Label: 0
# Input: [1, 5579] (['', 'overturned']) / Label: 0
# Input: [357, 6438] (['leader', "we'd"]) / Label: 0
# Input: [169, 5864] (['blair', 'supplied']) / Label: 0
# Input: [237, 20978] (['brown', '610']) / Label: 0
# Input: [2, 338] (['the', 'december']) / Label: 0
# Input: [600, 18574] (['union', 'kapor']) / Label: 0
# Input: [3938, 11139] (['rift', 'suez']) / Label: 0
# Input: [5, 7204] (['and', 'â£30']) / Label: 0
# Input: [1373, 14051] (['hits', 'textbook']) / Label: 0
# Input: [157, 7102] (['between', 'fold']) / Label: 0
# Input: [19, 24076] (['has', '1936']) / Label: 0
# Input: [6, 3326] (['a', 'rarely']) / Label: 0
# Input: [393, 5231] (['working', 'greeted']) / Label: 0
# Input: [912, 4530] (['himself', 'attitude']) / Label: 0
# Input: [7, 16555] (['in', 'reinstate']) / Label: 0
# Input: [2, 1700] (['the', 'organisations']) / Label: 0
# Input: [169, 29840] (['blair', 'connaught']) / Label: 0
# Input: [6, 15269] (['a', 'marley']) / Label: 0
# Input: [46, 5189] (['who', 'plastic']) / Label: 0
# Input: [237, 23174] (['brown', "mcintyre's"]) / Label: 0
# Input: [12, 28519] (['said', 'milestones']) / Label: 0
# Input: [1373, 12366] (['hits', 'bungie']) / Label: 0
# Input: [96, 22349] (['back', 'regency']) / Label: 0
# Input: [5, 8104] (['and', 'revolutionary']) / Label: 0
# Input: [1, 15524] (['', 'nomura']) / Label: 0
# Input: [2907, 30273] (['conflict', 'massachussetts']) / Label: 0
# Input: [46, 9240] (['who', "kelly's"]) / Label: 0
# Input: [1016, 914] (['row', "britain's"]) / Label: 0
# Input: [12, 29686] (['said', 'peng']) / Label: 0
# Input: [169, 7105] (['blair', 'begg']) / Label: 0
# Input: [600, 28473] (['union', "work's"]) / Label: 0
# Input: [19, 22088] (['has', 'kayitesi']) / Label: 0
# Input: [96, 649] (['back', 'apple']) / Label: 0
# Input: [487, 15494] (['tony', 'reais']) / Label: 0
# Input: [3938, 17450] (['rift', 'accomplishment']) / Label: 0
# Input: [760, 16380] (['gordon', "nhs's"]) / Label: 0
# Input: [14, 3578] (['was', 'tommy']) / Label: 0
# Input: [7, 29050] (['in', 'rhymes']) / Label: 0
# Input: [1239, 9290] (['criticised', 'conscience']) / Label: 0
# Input: [912, 28864] (['himself', 'jody']) / Label: 0
# Input: [157, 13983] (['between', 'hovering']) / Label: 0
# Input: [14, 12853] (['was', '96bn']) / Label: 0
# Input: [1239, 20952] (['criticised', 'contravene']) / Label: 0
# Input: [760, 25688] (['gordon', 'sharpening']) / Label: 0
# Input: [169, 24587] (['blair', 'lasp']) / Label: 0
# Input: [2907, 16910] (['conflict', 'headbutted']) / Label: 0
# Input: [237, 24092] (['brown', 'mcgreal']) / Label: 0
# Input: [357, 18904] (['leader', 'boon']) / Label: 0
# Input: [487, 17101] (['tony', 'oppressive']) / Label: 0
# Input: [1016, 11576] (['row', 'leoncia']) / Label: 0
# Input: [1, 11912] (['', 'unsubstantiated']) / Label: 0
# Input: [357, 1319] (['leader', 'buying']) / Label: 0
# Input: [169, 2537] (['blair', 'remove']) / Label: 0
# Input: [237, 4754] (['brown', 'fishing']) / Label: 0
# Input: [2, 21824] (['the', "washington's"]) / Label: 0
# Input: [600, 17610] (['union', 'cryotherapy']) / Label: 0
# Input: [3938, 11471] (['rift', 'robocop']) / Label: 0
# Input: [5, 313] (['and', 'away']) / Label: 0
# Input: [1373, 12207] (['hits', 'klinsmann']) / Label: 0
# Input: [157, 7129] (['between', 'curfews']) / Label: 0
# Input: [19, 14484] (['has', 'clamshell']) / Label: 0
# Input: [6, 17759] (['a', 'harrow']) / Label: 0
# Input: [393, 3891] (['working', 'reviews']) / Label: 0
# Input: [912, 5463] (['himself', 'opponent']) / Label: 0
# Input: [7, 16122] (['in', "amicus's"]) / Label: 0
# Input: [2, 16376] (['the', 'waterfront']) / Label: 0
# Input: [169, 19001] (['blair', 'trailers']) / Label: 0
# Input: [6, 22582] (['a', 'firearm']) / Label: 0
# Input: [46, 27602] (['who', 'adore']) / Label: 0
# Input: [237, 28388] (['brown', "saver'"]) / Label: 0
# Input: [12, 26637] (['said', "advertiser's"]) / Label: 0
# Input: [1373, 25922] (['hits', 'yankee']) / Label: 0
# Input: [96, 24894] (['back', 'snapshots']) / Label: 0
# Input: [5, 14327] (['and', "republic's"]) / Label: 0
# Input: [1, 28493] (['', 'mersey']) / Label: 0
# Input: [2907, 23898] (['conflict', 'tarnished']) / Label: 0
# Input: [46, 6063] (['who', '82']) / Label: 0
# Input: [1016, 22409] (['row', 'flexibly']) / Label: 0
# Input: [12, 28388] (['said', "saver'"]) / Label: 0
# Input: [169, 23300] (['blair', 'pascoe']) / Label: 0
# Input: [600, 28564] (['union', 'dutronc']) / Label: 0
# Input: [19, 21156] (['has', 'peirce']) / Label: 0
# Input: [96, 8999] (['back', 'timewarner']) / Label: 0
# Input: [487, 11117] (['tony', 'ifo']) / Label: 0
# Input: [3938, 21001] (['rift', 'upkeep']) / Label: 0
# Input: [760, 17485] (['gordon', 'surgener']) / Label: 0
# Input: [14, 26622] (['was', 'aura']) / Label: 0
# Input: [7, 2298] (['in', '60m']) / Label: 0
# Input: [1239, 23450] (['criticised', 'hudell']) / Label: 0
# Input: [912, 27594] (['himself', 'gatherings']) / Label: 0
# Input: [157, 18337] (['between', 'groundrules']) / Label: 0
# Input: [14, 13176] (['was', 'resignations']) / Label: 0
# Input: [1239, 8312] (['criticised', 'proven']) / Label: 0
# Input: [760, 9167] (['gordon', 'congratulated']) / Label: 0
# Input: [169, 12569] (['blair', 'addicted']) / Label: 0
# Input: [2907, 16694] (['conflict', 'disinterested']) / Label: 0
# Input: [237, 13779] (['brown', 'mccabe']) / Label: 0
# Input: [357, 1783] (['leader', 'fiat']) / Label: 0
# Input: [487, 18091] (['tony', 'nightclubs']) / Label: 0
# Input: [1016, 3030] (['row', 'subs']) / Label: 0
# Input: [1, 662] (['', 'shows']) / Label: 0
# Input: [357, 32353] (['leader', 'spray']) / Label: 0
# Input: [169, 26994] (['blair', 'herre']) / Label: 0
# Input: [237, 9108] (['brown', 'napier']) / Label: 0
# Input: [2, 16185] (['the', 'knighted']) / Label: 0
# Input: [600, 31231] (['union', 'dax']) / Label: 0
# Input: [3938, 19760] (['rift', 'earls']) / Label: 0
# Input: [5, 7924] (['and', 'gibbons']) / Label: 0
# Input: [1373, 20677] (['hits', 'horsham']) / Label: 0
# Input: [157, 30981] (['between', 'abd']) / Label: 0
# Input: [19, 15821] (['has', "services'"]) / Label: 0
# Input: [6, 952] (['a', 'challenge']) / Label: 0
# Input: [393, 22551] (['working', 'batten']) / Label: 0

# %%
batch_size = 4096 # Data points in a single batch

embedding_size = 128 # Dimension of the embedding vector.

window_size=1 # We use a window size of 1 on either side of target word
epochs = 5 # Number of epochs to train for
negative_samples = 4 # Number of negative samples generated per example

# We pick a random validation set to sample nearest neighbors
valid_size = 16 # Random set of words to evaluate similarity on.
# We sample valid datapoints randomly from a large window without always being deterministic
valid_window = 250

# When selecting valid examples, we select some of the most frequent words as well as
# some moderately rare words as well
np.random.seed(54321)
random.seed(54321)

valid_term_ids = np.array(random.sample(range(valid_window), valid_size))
valid_term_ids = np.append(
    valid_term_ids, random.sample(range(1000, 1000+valid_window), valid_size),
    axis=0
)

# %%
import tensorflow.keras.backend as K

K.clear_session()

# Inputs; target input layer will have the final shape [None]
# context will have [None, 2xwindow_size] shape
input_1 = tf.keras.layers.Input(shape=())
input_2 = tf.keras.layers.Input(shape=(window_size*2,))

# Target and context embedding layers
target_embedding_layer = tf.keras.layers.Embedding(
    input_dim=n_vocab, output_dim=embedding_size, name='target_embedding'
)

context_embedding_layer = tf.keras.layers.Embedding(
    input_dim=n_vocab, output_dim=embedding_size, name='context_embedding'
)

# Outputs of the target and context embedding lookups
context_out = context_embedding_layer(input_2)
target_out = target_embedding_layer(input_1)

# Taking the mean over the all the context words to produce [None, embedding_size]
mean_context_out = tf.keras.layers.Lambda(lambda x: tf.reduce_mean(x, axis=1))(context_out)

# Computing the dot product between the two
out = tf.keras.layers.Dot(axes=-1)([context_out, target_out])

cbow_model = tf.keras.models.Model(inputs=[input_1, input_2], outputs=out, name='cbow_model')

cbow_model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
    optimizer='adam'
)

cbow_model.summary()
# Out:
# Model: "cbow_model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 2)]                  0         []
#
#  input_1 (InputLayer)        [(None,)]                    0         []
#
#  context_embedding (Embeddi  (None, 2, 128)               1920128   ['input_2[0][0]']
#  ng)
#
#  target_embedding (Embeddin  (None, 128)                  1920128   ['input_1[0][0]']
#  g)
#
#  dot (Dot)                   (None, 2)                    0         ['context_embedding[0][0]',
#                                                                      'target_embedding[0][0]']
#
# ==================================================================================================
# Total params: 3840256 (14.65 MB)
# Trainable params: 3840256 (14.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
def cbow_data_generator(sequences, window_size, batch_size, negative_samples):

    rand_sequence_ids = np.arange(len(sequences))
    np.random.shuffle(rand_sequence_ids)

    for si in rand_sequence_ids:
        inputs, labels = cbow_grams(
            sequences[si],
            vocabulary_size=n_vocab,
            window_size=window_size,
            negative_samples=negative_samples,
            shuffle=True,
            sampling_table=sampling_table,
            seed=None
        )

        inputs_context, inputs_target, labels = np.array([inp[1] for inp in inputs]), np.array([inp[0] for inp in inputs]), np.array(labels).reshape(-1,1)

        assert inputs_context.shape[0] == inputs_target.shape[0]
        assert inputs_context.shape[0] == labels.shape[0]

        #print(inputs_context.shape, inputs_target.shape, labels.shape)
        for eg_id_start in range(0, inputs_context.shape[0], batch_size):

            yield (
                inputs_target[eg_id_start: min(eg_id_start+batch_size, inputs_target.shape[0])],
                inputs_context[eg_id_start: min(eg_id_start+batch_size, inputs_context.shape[0]),:]
            ), labels[eg_id_start: min(eg_id_start+batch_size, labels.shape[0])]

# %%
cbow_validation_callback = ValidationCallback(valid_term_ids, cbow_model, tokenizer)

for ei in range(epochs):
    print(f"Epoch: {ei+1}/{epochs} started")
    news_cbow_gen = cbow_data_generator(news_sequences, window_size, batch_size, negative_samples)
    cbow_model.fit(
        news_cbow_gen,
        epochs=1,
        callbacks=cbow_validation_callback,
    )
# Out:
# Epoch: 1/5 started
#    2225/Unknown - 188s 84ms/step - loss: 0.4612election: attorney, 250, resolution, one, aids
# me: manuel, goods, potential, we're, him
# with: epic, hewitt, they're, oscars, crowd
# you: almost, we, 19, him, screenplay
# were: are, i'm, use, 14, state
# win: hollywood's, â£1, currently, fan, men's
# those: edinburgh, sweeney, owners, brazilian, amount
# music: gmt, ran, currency, manufacturing, anniversary
# also: been, technological, working, politically, heavily
# international: katerina, tourist, crime, inflation, business
# best: transmission, talent, especially, norman, japan's
# him: lleyton, ran, jim, clark, cash
# too: mutual, ray, voted, gardener, profit
# into: wrote, oscar, variety, sony, greater
# through: favourite, network, wrote, ian, guitar
# mr: tony, dan, acknowledged, warned, entirely
# davis: among, scotland's, khodorkovsky, listed, kate
# concern: settlement, graham, application, ibm, msn
# trading: annual, headed, currency, design, helped
# critics: bruce, non, clark, leaving, graham
# post: brazilian, gmt, album, record, craig
# details: gary, strike, germany's, manufacturing, non
# approach: disney, jimmy, capital, ibm, pre
# previously: favourite, men's, currency, s, proposed
# measures: directors, bridge, insurers, musical, style
# actually: ran, included, gmt, referee, s
# deutsche: peter, plays, internal, becomes, jonathan
# leaders: interactive, jean, standing, musical, digital
# asylum: separate, women's, van, â£1, euronext
# attempt: brazilian, jim, musical, craig, aston
# reached: flow, standard, style, 43, ran
# illegal: non, weaker, peter, activity, we're
#
#
# 2226/2226 [==============================] - 188s 84ms/step - loss: 0.4611
# Epoch: 2/5 started
#    2226/Unknown - 117s 52ms/step - loss: 0.3975election: motors, attorney, letter, coming, development
# me: buyers, apparently, freeview, him, commission's
# with: epic, between, customer, across, seek
# you: we, they, i, not, don't
# were: are, i'm, do, being, already
# win: â£6, 11bn, hollywood's, ac, petrie
# those: emilio, heard, rarely, exercise, tarantino
# music: 100m, trophies, huw, chart, rating
# also: being, already, been, widely, i've
# international: actors, show's, katerina, rugby, category
# best: seeks, jail, model, honour, indeed
# him: usually, me, strongly, them, incidents
# too: better, less, relatively, very, holmes
# into: immediately, keep, i'm, further, extra
# through: martina, superior, weekend's, flu, slid
# mr: tony, charles, gordon, michael, said
# davis: m, fa, partner, g, khodorkovsky
# concern: faulty, proof, banking, pm, citizen
# trading: buckingham, confirms, breeding, swedish, olympics
# critics: rand, touched, missions, playwright, gilbert
# post: show's, prosecutor, 200m, runs, border
# details: lucrative, feeding, wartime, llanelli, winston
# approach: poetry, â£13m, israel's, berti, imf
# previously: emilio, lift, â£30, mexico's, merrill
# measures: lawsuit, proof, directors, mcilroy, indonesian
# actually: offside, skipper, create, absolutely, â£8
# deutsche: slipping, bartlett, sued, llanelli, rich
# leaders: unseeded, imaginary, tuesday's, sitcom, kenenisa
# asylum: flag, newsnight, ranieri, fletcher, pavey
# attempt: concrete, washington, enhance, channels, speakers
# reached: flow, 19th, poetry, sarbanes, loser
# illegal: austrian, ibm's, peace, luton, dropping
#
#
# 2226/2226 [==============================] - 117s 53ms/step - loss: 0.3975
# Epoch: 3/5 started
#    2226/Unknown - 114s 51ms/step - loss: 0.3748election: motors, attorney, forthcoming, campaign, labour's
# me: humans, confusion, apparently, 'to, unfounded
# with: honoured, bbc's, one's, proposal, visuals
# you: we, they, don't, i, really
# were: are, say, have, need, wasn't
# win: â£1, 1989, capital's, brazil, â£6
# those: internationally, mood, borrowing, websites, leaked
# music: satellite, containing, tv, hitch, unlimited
# also: already, widely, i've, being, everyone
# international: actors, rugby, leisure, 800m, brewer
# best: category, born, academy, meeting, areas
# him: them, themselves, me, usually, strongly
# too: very, so, better, bit, less
# into: directly, further, keep, indefinitely, around
# through: suffer, superior, u, directly, concerts
# mr: tony, gordon, bernie, charles, silk
# davis: carling, heineken, fa, uefa, partner
# concern: chain, salary, proof, secret, study
# trading: travis, expo, frequency, consultancy, steam
# critics: rand, programmers, gilbert, whip, noise
# post: ocean, brewer, triumph, anglo, resort
# details: polling, chat, factor, dispute, numbers
# approach: deterioration, scares, troncon, preparation, claxton's
# previously: originally, widely, already, we've, suit
# measures: proof, minor, lawsuit, mladenovic, screensaver
# actually: formally, neither, give, everyone, haven't
# deutsche: sina, pits, mia, jazz, slipping
# leaders: unseeded, relatives, corruption, ranked, anglo
# asylum: urges, ranieri, aus, shannon, agrees
# attempt: dramatic, upcoming, immediate, seeks, fog
# reached: ricardo, opel, warwick, mayor, tips
# illegal: thoday, scene, lifting, biography, 25bn
#
#
# 2226/2226 [==============================] - 114s 51ms/step - loss: 0.3748
# Epoch: 4/5 started
#    2225/Unknown - 112s 50ms/step - loss: 0.3548election: motors, attorney, elections, broad, forthcoming
# me: him, them, reportedly, thousands, tonight
# with: honoured, constructive, visuals, one's, atlantic
# you: we, they, i, don't, consumers
# were: are, need, say, insist, i'm
# win: 14, 24, 18, 13, 12
# those: internationally, owners, borrowing, traditionally, personalisation
# music: lifestyle, unlimited, satellite, video, tv
# also: already, previously, widely, decided, i've
# international: rugby, 800m, football, meeting, cinema
# best: category, nomination, supporting, crown, counterparts
# him: them, me, themselves, thousands, tories
# too: very, increasingly, so, extremely, bit
# into: further, around, indefinitely, directly, tactic
# through: edit, forms, functionality, maturity, visiting
# mr: tony, gordon, acknowledged, bernie, silk
# davis: uefa, heineken, carling, winner's, fa
# concern: carmaker, spokesperson, ground, liquidation, cbs
# trading: background, strongest, blow, forecasts, screened
# critics: compatible, antennae, kirkcaldy, programmers, sounded
# post: premiere, coveted, interpretation, pent, birthday
# details: numbers, ride, sativex, strictly, privatisation
# approach: deterioration, prudence, volley, preparation, cotton
# previously: already, widely, originally, i've, being
# measures: spokesperson, suit, proposals, saga, experts
# actually: certainly, always, probably, never, quite
# deutsche: boosts, sina, austria's, girl, austria
# leaders: amsterdam, unseeded, iv, scrutiny, modafinil
# asylum: awaiting, capability, curb, blocked, urges
# attempt: cairn's, rallies, grips, resource, holocaust
# reached: opel, basketball, discussed, worthington, exceeds
# illegal: networking, takeaway, person's, boring, leicester's
#
#
# 2226/2226 [==============================] - 112s 51ms/step - loss: 0.3548
# Epoch: 5/5 started
#    2226/Unknown - 112s 50ms/step - loss: 0.3375election: motors, broad, attorney, tv's, forthcoming
# me: him, them, reportedly, thousands, foreigners
# with: visuals, uncertainties, relaxation, carstairs, one's
# you: we, they, didn't, exactly, i
# were: are, insist, those, credible, have
# win: rupiah, 14, yuan, 24, â£8
# those: were, are, rarely, internationally, voters
# music: cameras, hp's, unlimited, video, divide
# also: already, previously, widely, decided, everyone
# international: policy, football, rugby, tennis, 800m
# best: category, nomination, celebrity, roles, counterparts
# him: them, me, themselves, anyone, tories
# too: very, extremely, so, increasingly, better
# into: through, hutton, directly, bust, indefinitely
# through: directly, across, prepare, forms, maturity
# mr: tony, acknowledged, gordon, ken, bernie
# davis: carling, heineken, uefa, winner's, fa
# concern: spokesperson, question, strength, optimism, settlement
# trading: symantec, advertised, tu, 11th, localised
# critics: commentators, stature, mafia, yahoo, objected
# post: interpretation, conviction, coveted, engineer, filippo
# details: dispute, passwords, strictly, operator's, length
# approach: prudence, deterioration, falsifying, usable, irrigation
# previously: already, widely, originally, i've, we've
# measures: spokesperson, proposals, proof, spells, landline
# actually: certainly, quite, always, he's, probably
# deutsche: boosts, austria's, austria, sina, prediction
# leaders: paula's, ephedrine, interests, modafinil, brothers'
# asylum: awaiting, urges, blocked, pearl, ranieri
# attempt: holocaust, resource, mistake, festivals, whitbread
# reached: farrell's, hacan, norwegian, alleging, exceeds
# illegal: semitic, mp3s, station's, goodwill, sour
#
#
# 2226/2226 [==============================] - 112s 50ms/step - loss: 0.3375

# %%
save_embeddings(cbow_model, tokenizer, n_vocab, save_dir='cbow_embeddings')

# %% [markdown]
# ## Visulizing the Learnings of the Skip-Gram Algorithm
# ### Loading skip-gram embeddings

# %%
skipgram_context_embeddings = pd.read_pickle(
    os.path.join('skipgram_embeddings', 'context_embedding.pkl')
)

skipgram_words, skipgram_embeddings = np.array(skipgram_context_embeddings.index), skipgram_context_embeddings.values

# %% [markdown]
# ### Finding Only the Words Clustered Together Instead of Sparsely Distributed Words

# %%
def find_clustered_embeddings(embeddings, top_n=10, top_words=2000):
    '''
    Find only the closely clustered embeddings.
    This gets rid of more sparsly distributed word embeddings and make the visualization clearer
    This is useful for t-SNE visualization

    distance_threshold: maximum distance between two points to qualify as neighbors
    sample_threshold: number of neighbors required to be considered a cluster
    '''

    # calculate cosine similarity
    embeddings_norm = embeddings / np.sum(embeddings**2, keepdims=True, axis=1)
    cosine_sim = np.dot(embeddings, embeddings.T)

    sim_sum_words = np.sum(np.sort(cosine_sim, axis=1)[:,-top_n:], axis=1)

    clustered_words = np.argsort(-sim_sum_words)[:top_words]

    return clustered_words

# %% [markdown]
# ### Computing the t-SNE Visualization of Word Embeddings Using Scikit-Learn

# %%
import sklearn

tsne = TSNE(
    perplexity=30, n_components=2, n_iter=5000, metric='cosine')

print('Fitting embeddings to T-SNE. This can take some time ...')
# get the T-SNE manifold

# prune the embeddings by getting ones only more than n-many sample above the similarity threshold
# this unclutters the visualization
plot_word_ids = find_clustered_embeddings(
    skipgram_embeddings, top_n=25, top_words=300
)

skipgram_embeddings_norm = skipgram_embeddings / np.sum(skipgram_embeddings**2, keepdims=True, axis=1)
tsne_embeddings = tsne.fit_transform(skipgram_embeddings_norm)

print('Pruning the T-SNE embeddings')

print('\tDone')
# Out:
# Fitting embeddings to T-SNE. This can take some time ...
# Pruning the T-SNE embeddings
# 	Done

# %% [markdown]
# ### Plotting the t-SNE Results with Matplotlib

# %%
def plot(embeddings, labels):
    print(f"Plotting {embeddings.shape[0]} points")
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'

    plt.figure(figsize=(15,15))  # in inches

    # plot all the embeddings and their corresponding words
    plot_annotations = []

    for i, label in enumerate(labels):

        x, y = embeddings[i,:]
        plt.scatter(x, y, alpha=0.25, c='gray')

        # We only annotate a small fraction of data, to avoid long waiting times
        if np.random.normal()>0.75:
            plot_annotations.append(
                plt.text(x, y, label, ha='center', va='center', fontsize=10)
            )

    print(
        f"Adjusting text annotations in the plot. This may take some time: Annotations {len(plot_annotations)}"
    )
    adjust_text(plot_annotations)

    # use for saving the figure if needed
    #plt.savefig('word_embeddings.png')
    plt.show()

# %%
cbow_context_embeddings = pd.read_pickle(
    os.path.join('cbow_embeddings', 'context_embedding.pkl')
)

cbow_words, cbow_embeddings = np.array(cbow_context_embeddings.index), cbow_context_embeddings.values

tsne = TSNE(perplexity=30, n_components=2, n_iter=5000, metric='cosine')

print('Fitting embeddings to T-SNE. This can take some time ...')
# get the T-SNE manifold

cbow_embeddings_norm = cbow_embeddings / np.sum(cbow_embeddings**2, keepdims=True, axis=1)
cbow_tsne_embeddings = tsne.fit_transform(cbow_embeddings_norm)

plot(cbow_tsne_embeddings[1:1501], cbow_words[1:1501])
# Out:
# Fitting embeddings to T-SNE. This can take some time ...
# Plotting 1500 points
# Adjusting text annotations in the plot. This may take some time: Annotations 349

# %% [markdown]
# ---
